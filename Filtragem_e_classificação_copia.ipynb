# %% [markdown]
# <a href="https://colab.research.google.com/github/phslopes/senai_python_data_science-/blob/main/Filtragem_e_classifica%C3%A7%C3%A3o_copia.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

df = pd.read_json('vinhos.json',lines=True)

df.head(5)
# Out:
#    year  month location location_type    category grape_type  volume_hl  \
# 0  2015      1       AC  Brazil_State  Production      Table        910
# 1  2015      1       AC  Brazil_State  Production       Wine       3822
# 2  2015      1       AC  Brazil_State  Production  Sparkling        516
# 3  2015      1       AC  Brazil_State       Sales      Table       3494
# 4  2015      1       AC  Brazil_State       Sales       Wine        180
#
#    value_usd
# 0    1782.31
# 1   11435.90
# 2     902.97
# 3   10491.74
# 4     279.26

# %%
df.shape
# Out:
# (26640, 8)

# %%
df.dtypes
# Out:
# year               int64
# month              int64
# location          object
# location_type     object
# category          object
# grape_type        object
# volume_hl          int64
# value_usd        float64
# dtype: object

# %%
df.describe()
# Out:
#                year         month     volume_hl    value_usd
# count  26640.000000  26640.000000  26640.000000  26640.00000
# mean    2019.500000      6.500000   2798.185135   8398.65186
# std        2.872335      3.452117   1666.405404   6071.43803
# min     2015.000000      1.000000     50.000000     87.07000
# 25%     2017.000000      3.750000   1393.000000   3721.98000
# 50%     2019.500000      6.500000   2736.000000   7368.98500
# 75%     2022.000000      9.250000   4068.000000  11741.85750
# max     2024.000000     12.000000   6996.000000  34273.99000

# %%
def2 = df.copy()
def2.loc[2:7,'month']= None
def2.loc[7:15,'volume_hl']= None
def2.loc[21:121,'value_usd']= None

def2.head(22)
# Out:
#     year  month location location_type    category grape_type  volume_hl  \
# 0   2015    1.0       AC  Brazil_State  Production      Table      910.0
# 1   2015    1.0       AC  Brazil_State  Production       Wine     3822.0
# 2   2015    NaN       AC  Brazil_State  Production  Sparkling      516.0
# 3   2015    NaN       AC  Brazil_State       Sales      Table     3494.0
# 4   2015    NaN       AC  Brazil_State       Sales       Wine      180.0
# 5   2015    NaN       AC  Brazil_State       Sales  Sparkling      819.0
# 6   2015    NaN       AC  Brazil_State  Production      Table     2483.0
# 7   2015    NaN       AC  Brazil_State  Production       Wine        NaN
# 8   2015    2.0       AC  Brazil_State  Production  Sparkling        NaN
# 9   2015    2.0       AC  Brazil_State       Sales      Table        NaN
# 10  2015    2.0       AC  Brazil_State       Sales       Wine        NaN
# 11  2015    2.0       AC  Brazil_State       Sales  Sparkling        NaN
# ...

# %%
def2.isnull().sum()
# Out:
# year               0
# month              6
# location           0
# location_type      0
# category           0
# grape_type         0
# volume_hl          9
# value_usd        101
# dtype: int64

# %%
def2.describe().T
# Out:
#              count         mean          std      min       25%     50%  \
# year       26640.0  2019.500000     2.872335  2015.00  2017.000  2019.5
# month      26634.0     6.501164     3.451628     1.00     4.000     7.0
# volume_hl  26631.0  2798.420337  1666.540874    50.00  1393.500  2736.0
# value_usd  26539.0  8404.921017  6077.246101    87.07  3723.795  7371.9
#
#                  75%       max
# year        2022.000   2024.00
# month         10.000     12.00
# volume_hl   4068.500   6996.00
# value_usd  11753.765  34273.99

# %%
df.describe().T
# Out:
#              count         mean          std      min      25%       50%  \
# year       26640.0  2019.500000     2.872335  2015.00  2017.00  2019.500
# month      26640.0     6.500000     3.452117     1.00     3.75     6.500
# volume_hl  26640.0  2798.185135  1666.405404    50.00  1393.00  2736.000
# value_usd  26640.0  8398.651860  6071.438030    87.07  3721.98  7368.985
#
#                   75%       max
# year        2022.0000   2024.00
# month          9.2500     12.00
# volume_hl   4068.0000   6996.00
# value_usd  11741.8575  34273.99

# %%
df1 = df.copy()
df1 = df1[(df1["grape_type"] == "Wine") & (df1["location_type"] == "Brazil_State")]
df1[(df1["grape_type"] == "Wine") & (df1["location_type"] == "Brazil_State")]
# Out:
#        year  month location location_type    category grape_type  volume_hl  \
# 1      2015      1       AC  Brazil_State  Production       Wine       3822
# 4      2015      1       AC  Brazil_State       Sales       Wine        180
# 7      2015      2       AC  Brazil_State  Production       Wine       1234
# 10     2015      2       AC  Brazil_State       Sales       Wine       1132
# 13     2015      3       AC  Brazil_State  Production       Wine       2784
# ...     ...    ...      ...           ...         ...        ...        ...
# 19426  2024     10       TO  Brazil_State       Sales       Wine       4114
# 19429  2024     11       TO  Brazil_State  Production       Wine       2551
# 19432  2024     11       TO  Brazil_State       Sales       Wine       1865
# 19435  2024     12       TO  Brazil_State  Production       Wine       1365
# 19438  2024     12       TO  Brazil_State       Sales       Wine        306
#
#        value_usd
# 1       11435.90
# 4         279.26
# ...

# %%
df2 = df.copy()
df2 = df2[(df2["grape_type"] == "Table") & (df2["category"] == "Sales")]
df2[(df2["grape_type"] == "Table") & (df2["category"] == "Sales")]
# Out:
#        year  month location location_type category grape_type  volume_hl  \
# 3      2015      1       AC  Brazil_State    Sales      Table       3494
# 9      2015      2       AC  Brazil_State    Sales      Table       2954
# 15     2015      3       AC  Brazil_State    Sales      Table       1578
# 21     2015      4       AC  Brazil_State    Sales      Table       1413
# 27     2015      5       AC  Brazil_State    Sales      Table       3893
# ...     ...    ...      ...           ...      ...        ...        ...
# 19413  2024      8       TO  Brazil_State    Sales      Table        679
# 19419  2024      9       TO  Brazil_State    Sales      Table       4955
# 19425  2024     10       TO  Brazil_State    Sales      Table       1754
# 19431  2024     11       TO  Brazil_State    Sales      Table       4277
# 19437  2024     12       TO  Brazil_State    Sales      Table       3391
#
#        value_usd
# 3       10491.74
# 9        6581.73
# 15       2550.25
# 21       2970.92
# ...

# %%
df1.describe().T
# Out:
#             count         mean          std      min      25%       50%  \
# year       6480.0  2019.500000     2.872503  2015.00  2017.00  2019.500
# month      6480.0     6.500000     3.452319     1.00     3.75     6.500
# volume_hl  6480.0  2535.696296  1434.656042    50.00  1278.75  2536.000
# value_usd  6480.0  6914.217131  4450.913281    88.09  3265.30  6395.285
#
#                  75%       max
# year       2022.0000   2024.00
# month         9.2500     12.00
# volume_hl  3783.2500   4999.00
# value_usd  9943.4625  19764.03

# %%
df2.describe().T
# Out:
#             count         mean          std      min        25%       50%  \
# year       3240.0  2019.500000     2.872725  2015.00  2017.0000  2019.500
# month      3240.0     6.500000     3.452585     1.00     3.7500     6.500
# volume_hl  3240.0  2493.430247  1420.835362    50.00  1266.0000  2479.000
# value_usd  3240.0  6883.208735  4409.919492    98.54  3294.2575  6385.715
#
#                75%       max
# year       2022.00   2024.00
# month         9.25     12.00
# volume_hl  3731.00   4998.00
# value_usd  9868.11  19388.56

# %% [markdown]
# 2 – Nestes dataFrames, ordene o ano de forma decrescente e o value_usd crescente. No fim, selecione as colunas year,
# grape_type, volume_hl, value_usd e location, nessa ordem. Use iloc[]

# %%
df1.sort_values(by=['year','value_usd'],ascending=[False,True],inplace=True)
df1
# Out:
# /tmp/ipython-input-249-1183854609.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df1.sort_values(by=['year','value_usd'],ascending=[False,True],inplace=True)
#        year  month location location_type    category grape_type  volume_hl  \
# 19369  2024      1       TO  Brazil_State  Production       Wine         72
# 5701   2024      3       ES  Brazil_State  Production       Wine         64
# 7897   2024      9       MT  Brazil_State  Production       Wine        145
# 12238  2024     12       PE  Brazil_State       Sales       Wine        134
# 1369   2024      1       AL  Brazil_State  Production       Wine        165
# ...     ...    ...      ...           ...         ...        ...        ...
# 16603  2015      8       SC  Brazil_State  Production       Wine       4952
# ...

# %%
df2.sort_values(by=['year','value_usd'],ascending=[False,True],inplace=True)
df2
# Out:
#        year  month location location_type category grape_type  volume_hl  \
# 651    2024      1       AC  Brazil_State    Sales      Table         78
# 19389  2024      4       TO  Brazil_State    Sales      Table         65
# 711    2024     11       AC  Brazil_State    Sales      Table         71
# 11451  2024      1       PR  Brazil_State    Sales      Table        116
# 17955  2024      5       SP  Brazil_State    Sales      Table         94
# ...     ...    ...      ...           ...      ...        ...        ...
# 10089  2015      2       PB  Brazil_State    Sales      Table       4889
# 4359   2015      7       DF  Brazil_State    Sales      Table       4303
# 10149  2015     12       PB  Brazil_State    Sales      Table       4960
# 6501   2015      4       MA  Brazil_State    Sales      Table       4778
# 2169   2015      2       AM  Brazil_State    Sales      Table       4955
#
#        value_usd
# 651       121.31
# 19389     131.62
# 711       186.79
# 11451     226.46
# ...

# %%
df1.iloc[:,[0,5,6,7,2]]
# Out:
#        year grape_type  volume_hl  value_usd location
# 19369  2024       Wine         72     112.63       TO
# 5701   2024       Wine         64     127.06       ES
# 7897   2024       Wine        145     222.00       MT
# 12238  2024       Wine        134     236.74       PE
# 1369   2024       Wine        165     248.81       AL
# ...     ...        ...        ...        ...      ...
# 16603  2015       Wine       4952   18174.78       SC
# 10090  2015       Wine       4624   18335.30       PB
# 17332  2015       Wine       4835   18465.64       SP
# 2212   2015       Wine       4725   18631.62       AM
# 13729  2015       Wine       4851   18696.27       RN
#
# [6480 rows x 5 columns]

# %%
df2.iloc[:,[0,5,6,7,2]]
# Out:
#        year grape_type  volume_hl  value_usd location
# 651    2024      Table         78     121.31       AC
# 19389  2024      Table         65     131.62       TO
# 711    2024      Table         71     186.79       AC
# 11451  2024      Table        116     226.46       PR
# 17955  2024      Table         94     305.52       SP
# ...     ...        ...        ...        ...      ...
# 10089  2015      Table       4889   17086.40       PB
# 4359   2015      Table       4303   17124.79       DF
# 10149  2015      Table       4960   18609.70       PB
# 6501   2015      Table       4778   18897.47       MA
# 2169   2015      Table       4955   18914.68       AM
#
# [3240 rows x 5 columns]

# %%
df1.reset_index(drop=True,inplace=True)
df1
# Out:
#       year  month location location_type    category grape_type  volume_hl  \
# 0     2024      1       TO  Brazil_State  Production       Wine         72
# 1     2024      3       ES  Brazil_State  Production       Wine         64
# 2     2024      9       MT  Brazil_State  Production       Wine        145
# 3     2024     12       PE  Brazil_State       Sales       Wine        134
# 4     2024      1       AL  Brazil_State  Production       Wine        165
# ...    ...    ...      ...           ...         ...        ...        ...
# 6475  2015      8       SC  Brazil_State  Production       Wine       4952
# 6476  2015      2       PB  Brazil_State       Sales       Wine       4624
# 6477  2015      9       SP  Brazil_State       Sales       Wine       4835
# 6478  2015      9       AM  Brazil_State       Sales       Wine       4725
# 6479  2015      9       RN  Brazil_State  Production       Wine       4851
#
#       value_usd
# 0        112.63
# 1        127.06
# ...

# %%
df2.reset_index(drop=True,inplace=True)
df2
# Out:
#       year  month location location_type category grape_type  volume_hl  \
# 0     2024      1       AC  Brazil_State    Sales      Table         78
# 1     2024      4       TO  Brazil_State    Sales      Table         65
# 2     2024     11       AC  Brazil_State    Sales      Table         71
# 3     2024      1       PR  Brazil_State    Sales      Table        116
# 4     2024      5       SP  Brazil_State    Sales      Table         94
# ...    ...    ...      ...           ...      ...        ...        ...
# 3235  2015      2       PB  Brazil_State    Sales      Table       4889
# 3236  2015      7       DF  Brazil_State    Sales      Table       4303
# 3237  2015     12       PB  Brazil_State    Sales      Table       4960
# 3238  2015      4       MA  Brazil_State    Sales      Table       4778
# 3239  2015      2       AM  Brazil_State    Sales      Table       4955
#
#       value_usd
# 0        121.31
# 1        131.62
# 2        186.79
# 3        226.46
# ...

# %%
df1.loc[1:10,]
# Out:
#     year  month location location_type    category grape_type  volume_hl  \
# 1   2024      3       ES  Brazil_State  Production       Wine         64
# 2   2024      9       MT  Brazil_State  Production       Wine        145
# 3   2024     12       PE  Brazil_State       Sales       Wine        134
# 4   2024      1       AL  Brazil_State  Production       Wine        165
# 5   2024     12       SP  Brazil_State       Sales       Wine        102
# 6   2024      7       SC  Brazil_State       Sales       Wine         93
# 7   2024      4       AM  Brazil_State       Sales       Wine        148
# 8   2024      9       PB  Brazil_State       Sales       Wine        161
# 9   2024      3       RO  Brazil_State       Sales       Wine        142
# 10  2024      7       PB  Brazil_State       Sales       Wine        206
#
#     value_usd
# 1      127.06
# 2      222.00
# 3      236.74
# 4      248.81
# 5      249.60
# 6      254.20
# 7      271.47
# 8      280.14
# 9      299.71
# ...

# %%
df2.loc[:10,]
# Out:
#     year  month location location_type category grape_type  volume_hl  \
# 0   2024      1       AC  Brazil_State    Sales      Table         78
# 1   2024      4       TO  Brazil_State    Sales      Table         65
# 2   2024     11       AC  Brazil_State    Sales      Table         71
# 3   2024      1       PR  Brazil_State    Sales      Table        116
# 4   2024      5       SP  Brazil_State    Sales      Table         94
# 5   2024      3       MA  Brazil_State    Sales      Table        135
# 6   2024      5       PB  Brazil_State    Sales      Table        138
# 7   2024      6       TO  Brazil_State    Sales      Table        204
# 8   2024      6       AC  Brazil_State    Sales      Table        166
# 9   2024      2       MT  Brazil_State    Sales      Table        164
# 10  2024      8       PI  Brazil_State    Sales      Table        214
#
#     value_usd
# 0      121.31
# 1      131.62
# 2      186.79
# 3      226.46
# 4      305.52
# 5      342.32
# 6      410.14
# ...

# %%
df1.dtypes
# Out:
# year               int64
# month              int64
# location          object
# location_type     object
# category          object
# grape_type        object
# volume_hl          int64
# value_usd        float64
# dtype: object

# %% [markdown]
# Exercícios Individuais – Limpeza e duplicados

# %%
df3 = df.copy()
df3.loc[2:7,'month']= None
df3.loc[7:15,'volume_hl']= None
df3.loc[21:121,'value_usd']= None

df3.shape
# Out:
# (26640, 8)

# %%
df3 = pd.concat([df3,df3])
df3.shape
# Out:
# (53280, 8)

# %%
df3.describe()
# Out:
#                year         month     volume_hl     value_usd
# count  53280.000000  53268.000000  53262.000000  53078.000000
# mean    2019.500000      6.501164   2798.420337   8404.921017
# std        2.872308      3.451595   1666.525229   6077.188851
# min     2015.000000      1.000000     50.000000     87.070000
# 25%     2017.000000      4.000000   1393.250000   3723.572500
# 50%     2019.500000      7.000000   2736.000000   7371.900000
# 75%     2022.000000     10.000000   4068.750000  11753.867500
# max     2024.000000     12.000000   6996.000000  34273.990000

# %%
df4 = df3.drop_duplicates()
df4.shape
# Out:
# (26640, 8)

# %%
df5 = df3.dropna()
df5.shape
# Out:
# (53050, 8)

# %%
df3.isnull().sum()
# Out:
# year               0
# month             12
# location           0
# location_type      0
# category           0
# grape_type         0
# volume_hl         18
# value_usd        202
# dtype: int64

# %%
df3.isnull().sum().sum()
# Out:
# np.int64(232)

# %%
dfFinal = df3.copy()
dfFinal.shape
# Out:
# (53280, 8)

# %%
dfFinal = dfFinal.drop_duplicates()
dfFinal.shape
# Out:
# (26640, 8)

# %%
mediana_sub = dfFinal['volume_hl'].median()
dfFinal = dfFinal['volume_hl'].fillna(mediana_sub)
mediana_sub
# Out:
# 2736.0

# %%
mediana_usd = dfFinal['value_usd'].median()
dfFinal = dfFinal['value_usd'].fillna(mediana_usd)
mediana_usd
# Out:
# 7371.9

# %%
print(f"final do dfFinal: {dfFinal.shape}")
# Out:
# final do dfFinal: (26640,)

# %%
print(f"final do df3: {df3.shape}")
# Out:
# final do df3: (53280, 8)

# %%
print(f"final do df: \n{df3.describe()}")
# Out:
# final do df:
#                year         month     volume_hl     value_usd
# count  53280.000000  53268.000000  53262.000000  53078.000000
# mean    2019.500000      6.501164   2798.420337   8404.921017
# std        2.872308      3.451595   1666.525229   6077.188851
# min     2015.000000      1.000000     50.000000     87.070000
# 25%     2017.000000      4.000000   1393.250000   3723.572500
# 50%     2019.500000      7.000000   2736.000000   7371.900000
# 75%     2022.000000     10.000000   4068.750000  11753.867500
# max     2024.000000     12.000000   6996.000000  34273.990000

# %%
print(f"final do dfFinal: \n{dfFinal.describe()}")
# Out:
# final do dfFinal:
# count    26640.000000
# mean      2798.399249
# std       1666.259725
# min         50.000000
# 25%       1394.000000
# 50%       2736.000000
# 75%       4068.000000
# max       6996.000000
# Name: volume_hl, dtype: float64

# %%
df['coisa_nova'] = df["grape_type"]
df.head()
# Out:
#    year  month location location_type    category grape_type  volume_hl  \
# 0  2015      1       AC  Brazil_State  Production      Table        910
# 1  2015      1       AC  Brazil_State  Production       Wine       3822
# 2  2015      1       AC  Brazil_State  Production  Sparkling        516
# 3  2015      1       AC  Brazil_State       Sales      Table       3494
# 4  2015      1       AC  Brazil_State       Sales       Wine        180
#
#    value_usd coisa_nova
# 0    1782.31      Table
# 1   11435.90       Wine
# 2     902.97  Sparkling
# 3   10491.74      Table
# 4     279.26       Wine
